# %% [markdown]
# # DisTrack : Training and Evaluation of model

# %% [markdown]
# ### 1. Imports

# %%
import sys
sys.path.append("..")
from utils.helper import save_file

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ### 2. Load and Train data

# %%
df = pd.read_csv("../data/labeled_logs.csv")

# %%
df
# Out:
#     hour  min                                      active_window  keystrokes  \
# 0     20   39  Haule Haule - Full Song | Rab Ne Bana Di Jodi ...          12
# 1     20   40          logger.py - DisTrack - Visual Studio Code           3
# 2     20   41                                           WhatsApp           2
# 3     20   42                                           WhatsApp           0
# 4     20   43                                   Spider Solitaire           0
# 5     20   44                                   Spider Solitaire           0
# 6     20   45                                   Spider Solitaire           2
# 7     20   46                                   Spider Solitaire           0
# 8     20   47                                   Spider Solitaire           0
# 9     20   48                                   Spider Solitaire           0
# 10    20   49                                    Program Manager           1
# 11    20   50                          Macromedia Flash Player 7           0
# 12    20   51                          Macromedia Flash Player 7           0
# 13    20   52                          Macromedia Flash Player 7           0
# 14    20   53                          Macromedia Flash Player 7           0
# 15    20   54                          Macromedia Flash Player 7           0
# 16    20   55                          Macromedia Flash Player 7           0
# 17    20   56                          Macromedia Flash Player 7           0
# 18    20   57                          Macromedia Flash Player 7           0
# 19    20   58                          Macromedia Flash Player 7           0
# 20    20   59                          Macromedia Flash Player 7           0
# 21    21    0                          Macromedia Flash Player 7           0
# 22    21    1                          Macromedia Flash Player 7           0
# 23    21    2                          Macromedia Flash Player 7           0
# 24    21    3                          Macromedia Flash Player 7           0
# 25    21    4                          Macromedia Flash Player 7           0
# 26    21    5                          Macromedia Flash Player 7           0
#
#     mouse_clicks  idle__time_sec       label  label_encoded
# 0              0          51.000     Focused              0
# 1              1          49.156     Focused              0
# 2              8           0.000     Focused              0
# 3              3           0.031     Focused              0
# 4             12           0.000     Focused              0
# 5             19           0.765     Focused              0
# 6             16           0.000     Focused              0
# 7             17           0.468     Focused              0
# 8             17           1.109     Focused              0
# 9             12           0.234     Neutral              1
# 10            17           0.016     Neutral              1
# 11            26           0.016     Neutral              1
# 12            31           0.016     Neutral              1
# 13            19           0.328     Neutral              1
# 14            21           0.016     Neutral              1
# 15            28           0.016     Neutral              1
# 16            17          22.562     Neutral              1
# 17             0          82.562     Neutral              1
# 18             0         142.562  Distracted              2
# 19             0         202.562  Distracted              2
# 20             0         262.562  Distracted              2
# 21             0         322.562  Distracted              2
# 22             0         382.562  Distracted              2
# 23             0         442.562  Distracted              2
# 24             0         502.562  Distracted              2
# 25             0         562.562  Distracted              2
# 26             0         622.562  Distracted              2

# %%
label_map = {
    "Focused" : 0,
    "Neutral" : 1,
    "Distracted" : 2
}

# %%
df["label_encoded"] = df["label"].map(label_map)

# %%
if "timestamp" in df.columns:
    df = df.drop(columns=["timestamp", "sl_no"])

# %%
df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 24)
df["minute_sin"] = np.sin(2 * np.pi * df["min"] / 60)
df["minute_cos"] = np.cos(2 * np.pi * df["min"] / 60)

df = df.drop(columns = ["hour", "min"])

# %%
X = df.drop(columns = ["label", "label_encoded"])
y = df["label"]

# %%
X
# Out:
#                                         active_window  keystrokes  \
# 0   Haule Haule - Full Song | Rab Ne Bana Di Jodi ...          12
# 1           logger.py - DisTrack - Visual Studio Code           3
# 2                                            WhatsApp           2
# 3                                            WhatsApp           0
# 4                                    Spider Solitaire           0
# 5                                    Spider Solitaire           0
# 6                                    Spider Solitaire           2
# 7                                    Spider Solitaire           0
# 8                                    Spider Solitaire           0
# 9                                    Spider Solitaire           0
# 10                                    Program Manager           1
# 11                          Macromedia Flash Player 7           0
# 12                          Macromedia Flash Player 7           0
# 13                          Macromedia Flash Player 7           0
# 14                          Macromedia Flash Player 7           0
# 15                          Macromedia Flash Player 7           0
# 16                          Macromedia Flash Player 7           0
# 17                          Macromedia Flash Player 7           0
# 18                          Macromedia Flash Player 7           0
# 19                          Macromedia Flash Player 7           0
# 20                          Macromedia Flash Player 7           0
# 21                          Macromedia Flash Player 7           0
# 22                          Macromedia Flash Player 7           0
# 23                          Macromedia Flash Player 7           0
# 24                          Macromedia Flash Player 7           0
# 25                          Macromedia Flash Player 7           0
# 26                          Macromedia Flash Player 7           0
#
#     mouse_clicks  idle__time_sec  hour_sin  hour_cos  minute_sin    minute_cos
# 0              0          51.000 -0.866025  0.500000   -0.809017 -5.877853e-01
# 1              1          49.156 -0.866025  0.500000   -0.866025 -5.000000e-01
# 2              8           0.000 -0.866025  0.500000   -0.913545 -4.067366e-01
# 3              3           0.031 -0.866025  0.500000   -0.951057 -3.090170e-01
# 4             12           0.000 -0.866025  0.500000   -0.978148 -2.079117e-01
# 5             19           0.765 -0.866025  0.500000   -0.994522 -1.045285e-01
# 6             16           0.000 -0.866025  0.500000   -1.000000 -1.836970e-16
# 7             17           0.468 -0.866025  0.500000   -0.994522  1.045285e-01
# 8             17           1.109 -0.866025  0.500000   -0.978148  2.079117e-01
# 9             12           0.234 -0.866025  0.500000   -0.951057  3.090170e-01
# 10            17           0.016 -0.866025  0.500000   -0.913545  4.067366e-01
# 11            26           0.016 -0.866025  0.500000   -0.866025  5.000000e-01
# 12            31           0.016 -0.866025  0.500000   -0.809017  5.877853e-01
# 13            19           0.328 -0.866025  0.500000   -0.743145  6.691306e-01
# 14            21           0.016 -0.866025  0.500000   -0.669131  7.431448e-01
# 15            28           0.016 -0.866025  0.500000   -0.587785  8.090170e-01
# 16            17          22.562 -0.866025  0.500000   -0.500000  8.660254e-01
# 17             0          82.562 -0.866025  0.500000   -0.406737  9.135455e-01
# 18             0         142.562 -0.866025  0.500000   -0.309017  9.510565e-01
# 19             0         202.562 -0.866025  0.500000   -0.207912  9.781476e-01
# 20             0         262.562 -0.866025  0.500000   -0.104528  9.945219e-01
# 21             0         322.562 -0.707107  0.707107    0.000000  1.000000e+00
# 22             0         382.562 -0.707107  0.707107    0.104528  9.945219e-01
# 23             0         442.562 -0.707107  0.707107    0.207912  9.781476e-01
# 24             0         502.562 -0.707107  0.707107    0.309017  9.510565e-01
# 25             0         562.562 -0.707107  0.707107    0.406737  9.135455e-01
# 26             0         622.562 -0.707107  0.707107    0.500000  8.660254e-01

# %%
categorial_features = ["active_window"]
numeric_features = [col for col in X.columns if col != "active_window"]

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorial_features),
        ('num', 'passthrough', numeric_features)
    ]
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=200, random_state=42))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %% [markdown]
# ### 3. Model Training

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['active_window']),
#                                                  ('num', 'passthrough',
#                                                   ['keystrokes', 'mouse_clicks',
#                                                    'idle__time_sec', 'hour_sin',
#                                                    'hour_cos', 'minute_sin',
#                                                    'minute_cos'])])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %% [markdown]
# ### 4. Predict and Evaluation

# %%
pred = pipeline.predict(X_test)

# %%
sum(pred == y_test) / len(y_test)
# Out:
# 1.0

# %% [markdown]
# ### 5. Save pipeline as pkl

# %%
save_file("pipeline.pkl", pipeline)

# %%
df
# Out:
#                                         active_window  keystrokes  \
# 0   Haule Haule - Full Song | Rab Ne Bana Di Jodi ...          12
# 1           logger.py - DisTrack - Visual Studio Code           3
# 2                                            WhatsApp           2
# 3                                            WhatsApp           0
# 4                                    Spider Solitaire           0
# 5                                    Spider Solitaire           0
# 6                                    Spider Solitaire           2
# 7                                    Spider Solitaire           0
# 8                                    Spider Solitaire           0
# 9                                    Spider Solitaire           0
# 10                                    Program Manager           1
# 11                          Macromedia Flash Player 7           0
# 12                          Macromedia Flash Player 7           0
# 13                          Macromedia Flash Player 7           0
# 14                          Macromedia Flash Player 7           0
# 15                          Macromedia Flash Player 7           0
# 16                          Macromedia Flash Player 7           0
# 17                          Macromedia Flash Player 7           0
# 18                          Macromedia Flash Player 7           0
# 19                          Macromedia Flash Player 7           0
# 20                          Macromedia Flash Player 7           0
# 21                          Macromedia Flash Player 7           0
# 22                          Macromedia Flash Player 7           0
# 23                          Macromedia Flash Player 7           0
# 24                          Macromedia Flash Player 7           0
# 25                          Macromedia Flash Player 7           0
# 26                          Macromedia Flash Player 7           0
#
#     mouse_clicks  idle__time_sec       label  label_encoded  hour_sin  \
# 0              0          51.000     Focused              0 -0.866025
# 1              1          49.156     Focused              0 -0.866025
# 2              8           0.000     Focused              0 -0.866025
# 3              3           0.031     Focused              0 -0.866025
# 4             12           0.000     Focused              0 -0.866025
# 5             19           0.765     Focused              0 -0.866025
# 6             16           0.000     Focused              0 -0.866025
# 7             17           0.468     Focused              0 -0.866025
# 8             17           1.109     Focused              0 -0.866025
# 9             12           0.234     Neutral              1 -0.866025
# 10            17           0.016     Neutral              1 -0.866025
# 11            26           0.016     Neutral              1 -0.866025
# 12            31           0.016     Neutral              1 -0.866025
# 13            19           0.328     Neutral              1 -0.866025
# 14            21           0.016     Neutral              1 -0.866025
# 15            28           0.016     Neutral              1 -0.866025
# 16            17          22.562     Neutral              1 -0.866025
# 17             0          82.562     Neutral              1 -0.866025
# 18             0         142.562  Distracted              2 -0.866025
# 19             0         202.562  Distracted              2 -0.866025
# 20             0         262.562  Distracted              2 -0.866025
# 21             0         322.562  Distracted              2 -0.707107
# 22             0         382.562  Distracted              2 -0.707107
# 23             0         442.562  Distracted              2 -0.707107
# 24             0         502.562  Distracted              2 -0.707107
# 25             0         562.562  Distracted              2 -0.707107
# 26             0         622.562  Distracted              2 -0.707107
#
#     hour_cos  minute_sin    minute_cos
# 0   0.500000   -0.809017 -5.877853e-01
# 1   0.500000   -0.866025 -5.000000e-01
# 2   0.500000   -0.913545 -4.067366e-01
# 3   0.500000   -0.951057 -3.090170e-01
# 4   0.500000   -0.978148 -2.079117e-01
# 5   0.500000   -0.994522 -1.045285e-01
# 6   0.500000   -1.000000 -1.836970e-16
# 7   0.500000   -0.994522  1.045285e-01
# 8   0.500000   -0.978148  2.079117e-01
# 9   0.500000   -0.951057  3.090170e-01
# 10  0.500000   -0.913545  4.067366e-01
# 11  0.500000   -0.866025  5.000000e-01
# 12  0.500000   -0.809017  5.877853e-01
# 13  0.500000   -0.743145  6.691306e-01
# 14  0.500000   -0.669131  7.431448e-01
# 15  0.500000   -0.587785  8.090170e-01
# 16  0.500000   -0.500000  8.660254e-01
# 17  0.500000   -0.406737  9.135455e-01
# 18  0.500000   -0.309017  9.510565e-01
# 19  0.500000   -0.207912  9.781476e-01
# 20  0.500000   -0.104528  9.945219e-01
# 21  0.707107    0.000000  1.000000e+00
# 22  0.707107    0.104528  9.945219e-01
# 23  0.707107    0.207912  9.781476e-01
# 24  0.707107    0.309017  9.510565e-01
# 25  0.707107    0.406737  9.135455e-01
# 26  0.707107    0.500000  8.660254e-01

# %%
df = {"active_window":"WhatsApp", 'keystrokes': 12,  'mouse_clicks': 5, 'idle__time_sec': 51.00, 'hour_sin' : -0.866025,	'hour_cos' : 0.500000	,	'minute_sin' : -0.809017,	'minute_cos' : -5.877853e-01}
pipeline.predict(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 df = {"active_window":"WhatsApp", 'keystrokes': 12,  'mouse_clicks': 5, 'idle__time_sec': 51.00, 'hour_sin' : -0.866025,	'hour_cos' : 0.500000	,	'minute_sin' : -0.809017,	'minute_cos' : -5.877853e-01}
# ----> 2 pipeline.predict(df)
#
# File H:\THOMSON\PROJECT\DisTrack\venv\Lib\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786 if not _routing_enabled():
#     787     for _, name, transform in self._iter(with_final=False):
# --> 788         Xt = transform.transform(Xt)
#     789     return self.steps[-1][1].predict(Xt, **params)
#     791 # metadata routing enabled
#
# File H:\THOMSON\PROJECT\DisTrack\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File H:\THOMSON\PROJECT\DisTrack\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:1056, in ColumnTransformer.transform(self, X, **params)
#    1054 _raise_for_params(params, self, "transform")
#    1055 check_is_fitted(self)
# -> 1056 X = _check_X(X)
#    1058 # If ColumnTransformer is fit using a dataframe, and now a dataframe is
#    1059 # passed to be transformed, we select columns by name instead. This
#    1060 # enables the user to pass X at transform time with extra columns which
#    1061 # were not present in fit time, and the order of the columns doesn't
#    1062 # matter.
#    1063 fit_dataframe_and_transform_dataframe = hasattr(self, "feature_names_in_") and (
#    1064     _is_pandas_df(X) or hasattr(X, "__dataframe__")
#    1065 )
#
# File H:\THOMSON\PROJECT\DisTrack\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:1338, in _check_X(X)
#    1332 if (
#    1333     (hasattr(X, "__array__") and hasattr(X, "shape"))
#    1334     or hasattr(X, "__dataframe__")
#    1335     or sparse.issparse(X)
#    1336 ):
#    1337     return X
# -> 1338 return check_array(X, ensure_all_finite="allow-nan", dtype=object)
#
# File H:\THOMSON\PROJECT\DisTrack\venv\Lib\site-packages\sklearn\utils\validation.py:1068, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1065 if ensure_2d:
#    1066     # If input is scalar raise error
#    1067     if array.ndim == 0:
# -> 1068         raise ValueError(
#    1069             "Expected 2D array, got scalar array instead:\narray={}.\n"
#    1070             "Reshape your data either using array.reshape(-1, 1) if "
#    1071             "your data has a single feature or array.reshape(1, -1) "
#    1072             "if it contains a single sample.".format(array)
#    1073         )
#    1074     # If input is 1D raise error
#    1075     if array.ndim == 1:
#    1076         # If input is a Series-like object (eg. pandas Series or polars Series)
#
# ValueError: Expected 2D array, got scalar array instead:
# array={'active_window': 'WhatsApp', 'keystrokes': 12, 'mouse_clicks': 5, 'idle__time_sec': 51.0, 'hour_sin': -0.866025, 'hour_cos': 0.5, 'minute_sin': -0.809017, 'minute_cos': -0.5877853}.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
