# %% [markdown]
# # DisTrack : Training and Evaluation of model

# %% [markdown]
# ### 1. Imports

# %%
import sys
sys.path.append("..")
from utils.helper import save_file, cleaner

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ### 2. Load and Prepare data

# %%
df
# Out:
#                                          active_window  keystrokes  \
# 0     life in limbo  oijage feat nick paona officia...           0
# 1     life in limbo  oijage feat nick paona officia...           0
# 2     life in limbo  oijage feat nick paona officia...           0
# 3     durand cup imphal 🏆  neroca vs real kashmir  ...           0
# 4     the final that stopped our hearts full highli...           0
# ..                                                 ...         ...
# 192  untitled and  more page  personal  microsoft​ ...           1
# 193  untitled and  more page  personal  microsoft​ ...          50
# 194  untitled and  more page  personal  microsoft​ ...           0
# 195  untitled and  more page  personal  microsoft​ ...           0
# 196  untitled and  more page  personal  microsoft​ ...           0
#
#      mouse_clicks  idle_time_sec  label_encoded  keystroke_per_sec  \
# 0               3         52.141              2           0.000000
# 1               0         15.235              2           0.000000
# 2               0         75.235              2           0.000000
# 3               3          3.031              2           0.000000
# 4               1         14.250              2           0.000000
# ..            ...            ...            ...                ...
# 192            10          0.125              0           0.016667
# 193             0          3.578              0           0.833333
# 194             0         63.578              0           0.000000
# 195             0        123.578              0           0.000000
# 196             0        183.578              0           0.000000
#
#      mouse_clicks_per_sec  activity_rate  idle_ratio  key_mouse_ratio  \
# 0                0.050000       0.338639    0.869017         0.000000
# 1                0.000000       0.000000    0.253917         0.000000
# 2                0.000000      -0.000000    1.253917         0.000000
# 3                0.050000       0.051752    0.050517         0.000000
# 4                0.016667       0.021390    0.237500         0.000000
# ..                    ...            ...         ...              ...
# 192              0.166667       0.180698    0.002083         0.090909
# 193              0.000000       0.870746    0.059633        50.000000
# 194              0.000000      -0.000000    1.059633         0.000000
# 195              0.000000      -0.000000    2.059633         0.000000
# 196              0.000000      -0.000000    3.059633         0.000000
#
#      idle_to_active_ratio
# 0               13.035250
# 1               15.235000
# 2               75.235000
# 3                0.757750
# 4                7.125000
# ..                    ...
# 192              0.010417
# 193              0.070157
# 194             63.578000
# 195            123.578000
# 196            183.578000
#
# [197 rows x 11 columns]

# %%
df = pd.read_csv("../data/1minDataset.csv")

# %%
label_map = {
    "Focused" : 0,
    "Neutral" : 1,
    "Distracted" : 2
}

df['active_window'] = df['active_window'].map(cleaner)
df["label_encoded"] = df["label"].map(label_map)

# %%
df = df.drop(columns = ["timestamp", "hour", "min", "label"])
#keep till future development

# %%
df['keystroke_per_sec'] = df['keystrokes'] / 60
df['mouse_clicks_per_sec'] = df['mouse_clicks'] / 60
df['activity_rate'] = (df['keystrokes'] + df['mouse_clicks']) / (60 - df['idle_time_sec'] + 1)

df['idle_ratio'] = df['idle_time_sec'] / 60
df['key_mouse_ratio'] = df['keystrokes'] / (df['mouse_clicks'] + 1)
df['idle_to_active_ratio'] = df['idle_time_sec'] / (df['keystrokes'] + df['mouse_clicks'] + 1)

# %% [markdown]
# ### 3. Train data

# %%
X = df.drop(columns = ["label_encoded"])
y = df["label_encoded"]

# %% [raw]
# df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
# df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 24)
# df["minute_sin"] = np.sin(2 * np.pi * df["min"] / 60)
# df["minute_cos"] = np.cos(2 * np.pi * df["min"] / 60)
#
# df = df.drop(columns = ["hour", "min"])
#
# for future development

# %%
numeric_features = [col for col in X.columns if col != "active_window"]

# %%
text_transformer = Pipeline(steps=[
     ('tfidf', TfidfVectorizer())   
])

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('text', text_transformer, 'active_window'),
        ('num', 'passthrough', numeric_features)
    ]
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=200, random_state=42))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %% [markdown]
# ### 4. Model Training

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('text',
#                                                   Pipeline(steps=[('tfidf',
#                                                                    TfidfVectorizer())]),
#                                                   'active_window'),
#                                                  ('num', 'passthrough',
#                                                   ['keystrokes', 'mouse_clicks',
#                                                    'idle_time_sec',
#                                                    'keystroke_per_sec',
#                                                    'mouse_clicks_per_sec',
#                                                    'activity_rate',
#                                                    'idle_ratio',
#                                                    'key_mouse_ratio',
#                                                    'idle_to_active_ratio'])])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %% [markdown]
# ### 4. Predict and Evaluation

# %%
pred = pipeline.predict(X_test)

# %%
sum(pred == y_test) / len(y_test)
# Out:
# 0.875

# %% [markdown]
# ### 5. Save pipeline as pkl

# %%
save_file("pipeline.pkl", pipeline)
